# %%
#Dependencies
import pandas as pd
import numpy as np
import tensorflow as tf
import itertools
import matplotlib.pyplot as plt
import time

from envs import OfflineEnv
from recommender import DRRAgent

import os

ROOT_DIR = os.getcwd()
DATA_DIR = os.path.join(ROOT_DIR, 'ml-1m')
STATE_SIZE = 10
# Out:
# 2023-02-03 11:04:26.666566: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #  Check Data

# %%
#Loading datasets
ratings_list = [i.strip().split("::") for i in open(os.path.join(DATA_DIR,'ratings.dat'), 'r').readlines()]
users_list = [i.strip().split("::") for i in open(os.path.join(DATA_DIR,'users.dat'), 'r').readlines()]
movies_list = [i.strip().split("::") for i in open(os.path.join(DATA_DIR,'movies.dat'),encoding='latin-1').readlines()]
ratings_df = pd.DataFrame(ratings_list, columns = ['UserID', 'MovieID', 'Rating', 'Timestamp'], dtype = np.uint32)
movies_df = pd.DataFrame(movies_list, columns = ['MovieID', 'Title', 'Genres'])
movies_df['MovieID'] = movies_df['MovieID'].apply(pd.to_numeric)
# Out:
# /tmp/ipykernel_1217/84107141.py:5: FutureWarning: Could not cast to uint32, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   ratings_df = pd.DataFrame(ratings_list, columns = ['UserID', 'MovieID', 'Rating', 'Timestamp'], dtype = np.uint32)

# %%
# moive id to movie title
movies_id_to_movies = {movie[0]: movie[1:] for movie in movies_list}

# %%
# number of movies
len(movies_list)
# Out:
# 3883

# %%
# check the ratings
ratings_df.head(5)
# Out:
#   UserID MovieID Rating  Timestamp
# 0      1    1193      5  978300760
# 1      1     661      3  978302109
# 2      1     914      3  978301968
# 3      1    3408      4  978300275
# 4      1    2355      5  978824291

# %%
# check the distribution of movies choosen by user
plt.figure(figsize=(20,10))
plt.hist(ratings_df["MovieID"], bins=100)
plt.show()

# %%
# check null
ratings_df.isnull().sum()
# Out:
# UserID       0
# MovieID      0
# Rating       0
# Timestamp    0
# dtype: int64

# %%
# check the maximum value of UserID
print(len(set(ratings_df["UserID"])) == max([int(i) for i in set(ratings_df["UserID"])]))
print(max([int(i) for i in set(ratings_df["UserID"])]))
# Out:
# True
# 6040

# %%
# make suer the ratings are integer
ratings_df = ratings_df.applymap(int)

# %%
# 유저별로 본 영화들 순서대로 정리
# make the user dictionary which have a value as movies list the user watched
users_dict = {user : [] for user in set(ratings_df["UserID"])}
users_dict[1]
# Out:
# []

# %%
# order the dataset by time
ratings_df = ratings_df.sort_values(by='Timestamp', ascending=True)
ratings_df.head(5)
# Out:
#          UserID  MovieID  Rating  Timestamp
# 1000138    6040      858       4  956703932
# 1000153    6040     2384       4  956703954
# 999873     6040      593       5  956703954
# 1000007    6040     1961       4  956703977
# 1000192    6040     2019       5  956703977

# %%
# add (movie, rating) pair to the user dictionary
## add movie rated >= 4 only
ratings_df_gen = ratings_df.iterrows()
users_dict_for_history_len = {user : [] for user in set(ratings_df["UserID"])}
for data in ratings_df_gen:
    users_dict[data[1]['UserID']].append((data[1]['MovieID'], data[1]['Rating']))
    if data[1]['Rating'] >= 4:
        users_dict_for_history_len[data[1]['UserID']].append((data[1]['MovieID'], data[1]['Rating']))

# %%
# the length of history for each user
users_history_lens = [len(users_dict_for_history_len[u]) for u in set(ratings_df["UserID"])]

# %%
# check the length of above list
len(users_history_lens)
# Out:
# 6040

# %%
# check the user dictionary
users_dict[1][:10]
# Out:
# [(3186, 4),
#  (1721, 4),
#  (1270, 5),
#  (1022, 5),
#  (2340, 3),
#  (1836, 5),
#  (3408, 4),
#  (1207, 4),
#  (2804, 5),
#  (260, 4)]

# %%
# save each data as npy to save time for future evaluation
np.save("./data/user_dict.npy", users_dict)
np.save("./data/users_histroy_len.npy", users_history_lens)

# %%
# get the number of users and items
users_num = max(ratings_df["UserID"])+1
items_num = max(ratings_df["MovieID"])+1

# %%
# check the following variables
print(users_num, items_num)
# Out:
# 6041 3953

# %% [markdown]
# ### setting for training dataset

# %%
train_users_num = int(users_num * 0.8)
train_items_num = items_num
print(train_users_num, train_items_num)
# Out:
# 4832 3953

# %%
train_users_dict = {k:users_dict[k] for k in range(1, train_users_num+1)}
train_users_history_lens = users_history_lens[:train_users_num]
print(len(train_users_dict),len(train_users_history_lens))
# Out:
# 4832 4832

# %% [markdown]
# ### setting for evaluation dataset

# %%
eval_users_num = int(users_num * 0.2)
eval_items_num = items_num
print(eval_users_num, eval_items_num)
# Out:
# 1208 3953

# %%
eval_users_dict = {k:users_dict[k] for k in range(users_num-eval_users_num, users_num)}
eval_users_history_lens = users_history_lens[-eval_users_num:]
print(len(eval_users_dict),len(eval_users_history_lens))
# Out:
# 1208 1208

# %% [markdown]
# ### the variables are ready
# - users_dict
# - users_history_len
# - movies_id_to_movies
# - users_num
# - items_num

# %% [markdown]
# # Evalutation

# %%
def evaluate(recommender, env, check_movies = False, top_k=False):

    # episodic reward 리셋
    episode_reward = 0
    steps = 0
    mean_precision = 0
    mean_ndcg = 0
    # Environment 리셋
    user_id, items_ids, done = env.reset()
    if check_movies:
        print(f'user_id : {user_id}, rated_items_length:{len(env.user_items)}')
        print('history items : \n', np.array(env.get_items_names(items_ids)))

    while not done:

        # Observe current state & Find action
        ## Embedding 해주기
        user_eb = recommender.embedding_network.get_layer('user_embedding')(np.array(user_id))
        items_eb = recommender.embedding_network.get_layer('movie_embedding')(np.array(items_ids))
        ## SRM으로 state 출력
        state = recommender.srm_ave([np.expand_dims(user_eb, axis=0), np.expand_dims(items_eb, axis=0)])
        ## Action(ranking score) 출력
        action = recommender.actor.network(state)
        ## Item 추천
        recommended_item = recommender.recommend_item(action, env.recommended_items, top_k=top_k)
        if check_movies:
            print(f'recommended items ids : {recommended_item}')
            print(f'recommened items : \n {np.array(env.get_items_names(recommended_item), dtype=object)}')
        # Calculate reward & observe new state (in env)
        ## Step
        next_items_ids, reward, done, _ = env.step(recommended_item, top_k=top_k)
        if top_k:
            correct_list = [1 if r > 0 else 0 for r in reward]
            # ndcg
            dcg, idcg = calculate_ndcg(correct_list, [1 for _ in range(len(reward))])
            mean_ndcg += dcg/idcg
            
            #precision
            correct_num = top_k-correct_list.count(0)
            mean_precision += correct_num/top_k
            
        reward = np.sum(reward)
        items_ids = next_items_ids
        episode_reward += reward
        steps += 1
        
        if check_movies:
            print(f'precision : {correct_num/top_k}, dcg : {dcg:0.3f}, idcg : {idcg:0.3f}, ndcg : {dcg/idcg:0.3f}, reward : {reward}')
            print()
        break
    
    if check_movies:
        print(f'precision : {mean_precision/steps}, ngcg : {mean_ndcg/steps}, episode_reward : {episode_reward}')
        print()
    
    return mean_precision/steps, mean_ndcg/steps

def calculate_ndcg(rel, irel):
    dcg = 0
    idcg = 0
    rel = [1 if r>0 else 0 for r in rel]
    for i, (r, ir) in enumerate(zip(rel, irel)):
        dcg += (r)/np.log2(i+2)
        idcg += (ir)/np.log2(i+2)
    return dcg, idcg

# %%
# get the saved model dir
saved_actor = './save_model/trail-2023-01-31-12/actor_1000_fixed.h5'
saved_critic = './save_model/trail-2023-01-31-12/critic_1000_fixed.h5'

# %%
tf.keras.backend.set_floatx('float64')

# %%
TOP_K = 10 # chose any k value as you want

sum_precision = 0
sum_ndcg = 0

# end_evaluation = 100

for i, user_id in enumerate(eval_users_dict.keys()):
    env = OfflineEnv(eval_users_dict, users_history_lens, movies_id_to_movies, STATE_SIZE, fix_user_id=user_id)
    recommender = DRRAgent(env, users_num, items_num, STATE_SIZE)
    recommender.actor.build_networks()
    recommender.critic.build_networks()
    recommender.load_model(saved_actor, saved_critic)
    precision, ndcg = evaluate(recommender, env, check_movies=True, top_k=TOP_K) # if check movies is true, you can check the recommended movies
    sum_precision += precision
    sum_ndcg += ndcg
    
    # if i > end_evaluation:
    #     break
print(f'precision@{TOP_K} : {sum_precision/len(eval_users_dict)}, ndcg@{TOP_K} : {sum_ndcg/len(eval_users_dict)}')
# Out:
# user_id : 4833, rated_items_length:81
# history items :
#  [['Vacation (1983)' 'Comedy']
#  ['Airplane II: The Sequel (1982)' 'Comedy']
#  ['In the Heat of the Night (1967)' 'Drama|Mystery']
#  ['Muppet Treasure Island (1996)' "Adventure|Children's|Comedy|Musical"]
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['Beauty and the Beast (1991)' "Animation|Children's|Musical"]
#  ['Mad Max 2 (a.k.a. The Road Warrior) (1981)' 'Action|Sci-Fi']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Amadeus (1984)' 'Drama']
#  ['Grapes of Wrath, The (1940)' 'Drama']]
# recommended items ids : [2571  527 1197 1240  589 2028 1210 1198 1196  260]
# recommened items :
#  [['Matrix, The (1999)' 'Action|Sci-Fi|Thriller']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Terminator, The (1984)' 'Action|Sci-Fi|Thriller']
#  ['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.4, dcg : 2.090, idcg : 4.544, ndcg : 0.460, reward : 0.5
#
# precision : 0.4, ngcg : 0.46001266110046096, episode_reward : 0.5
#
# user_id : 4834, rated_items_length:280
# history items :
#  [['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Boxing Helena (1993)' 'Mystery|Romance|Thriller']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ["Breakfast at Tiffany's (1961)" 'Drama|Romance']
#  ['Mrs. Doubtfire (1993)' 'Comedy']
#  ['Ponette (1996)' 'Drama']
#  ['To Kill a Mockingbird (1962)' 'Drama']
#  ['Central Station (Central do Brasil) (1998)' 'Drama']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']]
# recommended items ids : [3175  110  457 2571  527 1198  260 2028 2762 1196]
# recommened items :
#  [['Galaxy Quest (1999)' 'Adventure|Comedy|Sci-Fi']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['Fugitive, The (1993)' 'Action|Thriller']
#  ['Matrix, The (1999)' 'Action|Sci-Fi|Thriller']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']]
# precision : 0.9, dcg : 4.228, idcg : 4.544, ndcg : 0.931, reward : 5.0
#
# precision : 0.9, ngcg : 0.9305687780632227, episode_reward : 5.0
#
# user_id : 4835, rated_items_length:83
# history items :
#  [['Dave (1993)' 'Comedy|Romance']
#  ['Santa Clause, The (1994)' "Children's|Comedy|Fantasy"]
#  ['Batman: Mask of the Phantasm (1993)' "Animation|Children's"]
#  ["Amityville 1992: It's About Time (1992)" 'Horror']
#  ['North by Northwest (1959)' 'Drama|Thriller']
#  ['Just Cause (1995)' 'Mystery|Thriller']
#  ['East of Eden (1955)' 'Drama']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['L.A. Story (1991)' 'Comedy|Romance']
#  ['Alien Nation (1988)' 'Crime|Drama|Sci-Fi']]
# recommended items ids : [2571 1198  589 2028 1210  527  110 1196 2858  260]
# recommened items :
#  [['Matrix, The (1999)' 'Action|Sci-Fi|Thriller']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.7, dcg : 3.467, idcg : 4.544, ndcg : 0.763, reward : 5.0
#
# precision : 0.7, ngcg : 0.7630946912803436, episode_reward : 5.0
#
# user_id : 4836, rated_items_length:65
# history items :
#  [['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Splash (1984)' 'Comedy|Fantasy|Romance']
#  ['Yellow Submarine (1968)' 'Animation|Musical']
#  ['On Golden Pond (1981)' 'Drama']
#  ['Stigmata (1999)' 'Thriller']
#  ["They Shoot Horses, Don't They? (1969)" 'Drama']
#  ['Patriot, The (2000)' 'Action|Drama|War']
#  ['Myth of Fingerprints, The (1997)' 'Comedy|Drama']
#  ['Before the Rain (Pred dozhdot) (1994)' 'Drama']
#  ["Schindler's List (1993)" 'Drama|War']]
# recommended items ids : [1617 2571  589 1196 1198  858 2028  608  593 2858]
# recommened items :
#  [['L.A. Confidential (1997)' 'Crime|Film-Noir|Mystery|Thriller']
#  ['Matrix, The (1999)' 'Action|Sci-Fi|Thriller']
#  ['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['American Beauty (1999)' 'Comedy|Drama']]
# precision : 0.3, dcg : 0.923, idcg : 4.544, ndcg : 0.203, reward : -1.0
#
# precision : 0.3, ngcg : 0.2032389337527008, episode_reward : -1.0
#
# user_id : 4837, rated_items_length:328
# history items :
#  [['Kiss of Death (1995)' 'Crime|Drama|Thriller']
#  ['Operation Condor (Feiying gaiwak) (1990)' 'Action|Adventure|Comedy']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['Rocky II (1979)' 'Action|Drama']
#  ['Original Gangstas (1996)' 'Crime']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Nightmare on Elm Street 5: The Dream Child, A (1989)' 'Horror']
#  ['New Jersey Drive (1995)' 'Crime|Drama']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Assault on Precinct 13 (1976)' 'Action|Thriller']]
# recommended items ids : [1197  318 1270 2028 2858 1036  593 1198  260 1196]
# recommened items :
#  [['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Shawshank Redemption, The (1994)' 'Drama']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Die Hard (1988)' 'Action|Thriller']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']]
# precision : 0.2, dcg : 1.500, idcg : 4.544, ndcg : 0.330, reward : -2.5
#
# precision : 0.2, ngcg : 0.33013764944712026, episode_reward : -2.5
#
# user_id : 4838, rated_items_length:39
# history items :
#  [['Adventures of Milo and Otis, The (1986)' "Children's"]
#  ['Honey, I Shrunk the Kids (1989)'
#   "Adventure|Children's|Comedy|Fantasy|Sci-Fi"]
#  ['Gone with the Wind (1939)' 'Drama|Romance|War']
#  ['Aladdin and the King of Thieves (1996)' "Animation|Children's|Comedy"]
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Adventures of Rocky and Bullwinkle, The (2000)'
#   "Animation|Children's|Comedy"]
#  ['Chicken Run (2000)' "Animation|Children's|Comedy"]
#  ['Paulie (1998)' "Adventure|Children's|Comedy"]
#  ['Dances with Wolves (1990)' 'Adventure|Drama|Western']
#  ['Secret of Roan Inish, The (1994)' 'Drama']]
# recommended items ids : [ 858 2762 3114    1 1210  593 1270 1198 1196  260]
# recommened items :
#  [['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Toy Story 2 (1999)' "Animation|Children's|Comedy"]
#  ['Toy Story (1995)' "Animation|Children's|Comedy"]
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.0, dcg : 0.000, idcg : 4.544, ndcg : 0.000, reward : -5.0
#
# precision : 0.0, ngcg : 0.0, episode_reward : -5.0
#
# user_id : 4839, rated_items_length:23
# history items :
#  [['Papillon (1973)' 'Drama']
#  ['Sleeper (1973)' 'Comedy|Sci-Fi']
#  ['Dave (1993)' 'Comedy|Romance']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['Get Shorty (1995)' 'Action|Comedy|Drama']
#  ['Titanic (1997)' 'Drama|Romance']
#  ['Limey, The (1999)' 'Action|Crime|Drama']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Insider, The (1999)' 'Drama']
#  ['American Beauty (1999)' 'Comedy|Drama']]
# recommended items ids : [1193 1387 1097 1270  858  593  527 1198 1196  260]
# recommened items :
#  [["One Flew Over the Cuckoo's Nest (1975)" 'Drama']
#  ['Jaws (1975)' 'Action|Horror']
#  ['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.0, dcg : 0.000, idcg : 4.544, ndcg : 0.000, reward : -5.0
#
# precision : 0.0, ngcg : 0.0, episode_reward : -5.0
#
# user_id : 4840, rated_items_length:72
# history items :
#  [['Midnight in the Garden of Good and Evil (1997)'
#   'Comedy|Crime|Drama|Mystery']
#  ['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ['L.A. Confidential (1997)' 'Crime|Film-Noir|Mystery|Thriller']
#  ['Karate Kid III, The (1989)' 'Action|Adventure|Drama']
#  ['Forrest Gump (1994)' 'Comedy|Romance|War']
#  ['True Grit (1969)' 'Adventure|Western']
#  ['Searchers, The (1956)' 'Western']
#  ['Butch Cassidy and the Sundance Kid (1969)' 'Action|Comedy|Western']
#  ['Unforgiven (1992)' 'Western']
#  ['Dances with Wolves (1990)' 'Adventure|Drama|Western']]
# recommended items ids : [ 318 1270 2571 1210 1198 1197 1196  527  260 2762]
# recommened items :
#  [['Shawshank Redemption, The (1994)' 'Drama']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Matrix, The (1999)' 'Action|Sci-Fi|Thriller']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Sixth Sense, The (1999)' 'Thriller']]
# precision : 0.3, dcg : 1.605, idcg : 4.544, ndcg : 0.353, reward : -0.5
#
# precision : 0.3, ngcg : 0.3531437764338092, episode_reward : -0.5
#
# user_id : 4841, rated_items_length:92
# history items :
#  [['Forrest Gump (1994)' 'Comedy|Romance|War']
#  ['Mulholland Falls (1996)' 'Crime|Film-Noir|Thriller']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Hook (1991)' 'Adventure|Fantasy']
#  ['Casino (1995)' 'Drama|Thriller']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Croupier (1998)' 'Crime|Drama']
#  ['Chicken Run (2000)' "Animation|Children's|Comedy"]
#  ['Hamlet (2000)' 'Drama']
#  ['Big Kahuna, The (2000)' 'Comedy|Drama']]
# recommended items ids : [3114    1 2858 1210  527 1270  608  593  260 1196]
# recommened items :
#  [['Toy Story 2 (1999)' "Animation|Children's|Comedy"]
#  ['Toy Story (1995)' "Animation|Children's|Comedy"]
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']]
# precision : 0.5, dcg : 2.863, idcg : 4.544, ndcg : 0.630, reward : 0.5
#
# precision : 0.5, ngcg : 0.6300426811446146, episode_reward : 0.5
#
# user_id : 4842, rated_items_length:69
# history items :
#  [['Plan 9 from Outer Space (1958)' 'Horror|Sci-Fi']
#  ['Casablanca (1942)' 'Drama|Romance|War']
#  ['EDtv (1999)' 'Comedy']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Irma la Douce (1963)' 'Comedy']
#  ['American Tail, An (1986)' "Animation|Children's|Comedy"]
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Being John Malkovich (1999)' 'Comedy']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Limey, The (1999)' 'Action|Crime|Drama']]
# recommended items ids : [1270  608 1097 1210  527  858 1198 1196  593  260]
# recommened items :
#  [['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.5, dcg : 1.778, idcg : 4.544, ndcg : 0.391, reward : 1.5
#
# precision : 0.5, ngcg : 0.3913817611255761, episode_reward : 1.5
#
# user_id : 4843, rated_items_length:116
# history items :
#  [['Fatal Attraction (1987)' 'Thriller']
#  ['Jurassic Park (1993)' 'Action|Adventure|Sci-Fi']
#  ['Mrs. Brown (Her Majesty, Mrs. Brown) (1997)' 'Drama|Romance']
#  ['Moonstruck (1987)' 'Comedy']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Blowup (1966)' 'Drama|Mystery']
#  ['Hamlet (1990)' 'Drama']
#  ['Tango (1998)' 'Drama']
#  ['400 Blows, The (Les Quatre cents coups) (1959)' 'Drama']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']]
# recommended items ids : [1197  608  912  593 2858  527 1210 1198 1196  260]
# recommened items :
#  [['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Casablanca (1942)' 'Drama|Romance|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.3, dcg : 1.562, idcg : 4.544, ndcg : 0.344, reward : -0.5
#
# precision : 0.3, ngcg : 0.3436966913921454, episode_reward : -0.5
#
# user_id : 4844, rated_items_length:29
# history items :
#  [["Jumpin' Jack Flash (1986)" 'Action|Comedy|Romance|Thriller']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['McCabe & Mrs. Miller (1971)' 'Drama|Western']
#  ['L.A. Confidential (1997)' 'Crime|Film-Noir|Mystery|Thriller']
#  ['Mrs. Winterbourne (1996)' 'Comedy|Romance']
#  ["Gentleman's Agreement (1947)" 'Drama']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Talented Mr. Ripley, The (1999)' 'Drama|Mystery|Thriller']
#  ['World Is Not Enough, The (1999)' 'Action|Thriller']
#  ['Star Wars: Episode I - The Phantom Menace (1999)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# recommended items ids : [1196 1097  318  110  527 2028 2762 1270  260 1198]
# recommened items :
#  [['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ['Shawshank Redemption, The (1994)' 'Drama']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']]
# precision : 0.2, dcg : 0.764, idcg : 4.544, ndcg : 0.168, reward : -2.0
#
# precision : 0.2, ngcg : 0.1681522864689108, episode_reward : -2.0
#
# user_id : 4845, rated_items_length:153
# history items :
#  [["Schindler's List (1993)" 'Drama|War']
#  ['Stepmom (1998)' 'Drama']
#  ["Nobody's Fool (1994)" 'Drama']
#  ["One Flew Over the Cuckoo's Nest (1975)" 'Drama']
#  ['Right Stuff, The (1983)' 'Drama']
#  ['Local Hero (1983)' 'Comedy']
#  ['Children of the Corn II: The Final Sacrifice (1993)' 'Horror']
#  ['Trainspotting (1996)' 'Drama']
#  ['Shop Around the Corner, The (1940)' 'Comedy|Romance']
#  ['Rebecca (1940)' 'Romance|Thriller']]
# recommended items ids : [ 296 2028  608 2858 1198 1210  260  593 1197 1196]
# recommened items :
#  [['Pulp Fiction (1994)' 'Crime|Drama']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']]
# precision : 0.4, dcg : 1.588, idcg : 4.544, ndcg : 0.349, reward : 0.0
#
# precision : 0.4, ngcg : 0.34948673995165525, episode_reward : 0.0
#
# user_id : 4846, rated_items_length:30
# history items :
#  [['Home Alone (1990)' "Children's|Comedy"]
#  ['Godfather: Part II, The (1974)' 'Action|Crime|Drama']
#  ['Grosse Pointe Blank (1997)' 'Comedy|Crime']
#  ['Moonstruck (1987)' 'Comedy']
#  ["My Best Friend's Wedding (1997)" 'Comedy|Romance']
#  ['Tin Cup (1996)' 'Comedy|Romance']
#  ['Ref, The (1994)' 'Comedy']
#  ['Godfather: Part III, The (1990)' 'Action|Crime|Drama']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Green Mile, The (1999)' 'Drama|Thriller']]
# recommended items ids : [ 318 1097 1196  527  593    1 1198  260 3114  608]
# recommened items :
#  [['Shawshank Redemption, The (1994)' 'Drama']
#  ['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Toy Story (1995)' "Animation|Children's|Comedy"]
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Toy Story 2 (1999)' "Animation|Children's|Comedy"]
#  ['Fargo (1996)' 'Crime|Drama|Thriller']]
# precision : 0.0, dcg : 0.000, idcg : 4.544, ndcg : 0.000, reward : -5.0
#
# precision : 0.0, ngcg : 0.0, episode_reward : -5.0
#
# user_id : 4847, rated_items_length:72
# history items :
#  [['Blade Runner (1982)' 'Film-Noir|Sci-Fi']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Toy Story 2 (1999)' "Animation|Children's|Comedy"]
#  ['Get Shorty (1995)' 'Action|Comedy|Drama']
#  ['Annie Hall (1977)' 'Comedy|Romance']
#  ['Taxi Driver (1976)' 'Drama|Thriller']
#  ['Blood Simple (1984)' 'Drama|Film-Noir']
#  ['Close Shave, A (1995)' 'Animation|Comedy|Thriller']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Usual Suspects, The (1995)' 'Crime|Thriller']]
# recommended items ids : [ 589  527 2762  593 1197 1270 2858 1198 1196  260]
# recommened items :
#  [['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.5, dcg : 1.922, idcg : 4.544, ndcg : 0.423, reward : 2.0
#
# precision : 0.5, ngcg : 0.4230293752959408, episode_reward : 2.0
#
# user_id : 4848, rated_items_length:54
# history items :
#  [["Schindler's List (1993)" 'Drama|War']
#  ["One Flew Over the Cuckoo's Nest (1975)" 'Drama']
#  ['Tales from the Darkside: The Movie (1990)' 'Horror']
#  ['Die Hard 2 (1990)' 'Action|Thriller']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Arachnophobia (1990)' 'Action|Comedy|Sci-Fi|Thriller']
#  ['Abyss, The (1989)' 'Action|Adventure|Sci-Fi|Thriller']
#  ['Bone Collector, The (1999)' 'Thriller']
#  ['Blair Witch Project, The (1999)' 'Horror']
#  ['Clan of the Cave Bear, The (1986)' 'Drama']]
# recommended items ids : [1617 1387  593 1097 2028 2858 1270 1210 1196  260]
# recommened items :
#  [['L.A. Confidential (1997)' 'Crime|Film-Noir|Mystery|Thriller']
#  ['Jaws (1975)' 'Action|Horror']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.2, dcg : 0.688, idcg : 4.544, ndcg : 0.151, reward : -1.5
#
# precision : 0.2, ngcg : 0.15139734109601002, episode_reward : -1.5
#
# user_id : 4849, rated_items_length:157
# history items :
#  [['Blast from the Past (1999)' 'Comedy|Romance']
#  ['Rain Man (1988)' 'Drama']
#  ['Friday the 13th Part 2 (1981)' 'Horror']
#  ['Mortal Kombat: Annihilation (1997)' 'Action|Adventure']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['13th Warrior, The (1999)' 'Action|Horror|Thriller']
#  ['American Pie (1999)' 'Comedy']
#  ['10 Things I Hate About You (1999)' 'Comedy|Romance']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Austin Powers: The Spy Who Shagged Me (1999)' 'Comedy']]
# recommended items ids : [2571 1270  593  356  318  260 1198 2028 1196 1210]
# recommened items :
#  [['Matrix, The (1999)' 'Action|Sci-Fi|Thriller']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Forrest Gump (1994)' 'Comedy|Romance|War']
#  ['Shawshank Redemption, The (1994)' 'Drama']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']]
# precision : 0.8, dcg : 3.157, idcg : 4.544, ndcg : 0.695, reward : 5.5
#
# precision : 0.8, ngcg : 0.6947651160602989, episode_reward : 5.5
#
# user_id : 4850, rated_items_length:37
# history items :
#  [['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Bridge on the River Kwai, The (1957)' 'Drama|War']
#  ['Beverly Hillbillies, The (1993)' 'Comedy']
#  ['Fools Rush In (1997)' 'Comedy|Romance']
#  ['Star Wars: Episode I - The Phantom Menace (1999)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Return to Me (2000)' 'Drama|Romance']
#  ['Me, Myself and Irene (2000)' 'Comedy']
#  ['Where the Heart Is (2000)' 'Comedy|Drama']
#  ['Adventures of Rocky and Bullwinkle, The (2000)'
#   "Animation|Children's|Comedy"]
#  ['Mission: Impossible 2 (2000)' 'Action|Thriller']]
# recommended items ids : [2858  318  858 1270 1196  608 1198  260  527  593]
# recommened items :
#  [['American Beauty (1999)' 'Comedy|Drama']
#  ['Shawshank Redemption, The (1994)' 'Drama']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']]
# precision : 0.3, dcg : 1.021, idcg : 4.544, ndcg : 0.225, reward : -0.5
#
# precision : 0.3, ngcg : 0.22466337602289155, episode_reward : -0.5
#
# user_id : 4851, rated_items_length:24
# history items :
#  [['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Dogma (1999)' 'Comedy']
#  ['Married to the Mob (1988)' 'Comedy']
#  ['Superman IV: The Quest for Peace (1987)' 'Action|Adventure|Sci-Fi']
#  ['Rocky II (1979)' 'Action|Drama']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['American Pie (1999)' 'Comedy']
#  ['28 Days (2000)' 'Comedy']
#  ['Austin Powers: The Spy Who Shagged Me (1999)' 'Comedy']]
# recommended items ids : [1387 1210 1193 1198  593  608  356 1196  260  527]
# recommened items :
#  [['Jaws (1975)' 'Action|Horror']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ["One Flew Over the Cuckoo's Nest (1975)" 'Drama']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Forrest Gump (1994)' 'Comedy|Romance|War']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ["Schindler's List (1993)" 'Drama|War']]
# precision : 0.0, dcg : 0.000, idcg : 4.544, ndcg : 0.000, reward : -5.0
#
# precision : 0.0, ngcg : 0.0, episode_reward : -5.0
#
# user_id : 4852, rated_items_length:243
# history items :
#  [['Streetcar Named Desire, A (1951)' 'Drama']
#  ["Devil's Own, The (1997)" 'Action|Drama|Thriller|War']
#  ['Demolition Man (1993)' 'Action|Sci-Fi']
#  ['Breakfast Club, The (1985)' 'Comedy|Drama']
#  ["Soldier's Story, A (1984)" 'Drama']
#  ['Song of the South (1946)' "Adventure|Animation|Children's|Musical"]
#  ['Thunderbolt and Lightfoot (1974)' 'Action']
#  ['Raisin in the Sun, A (1961)' 'Drama']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Blowup (1966)' 'Drama|Mystery']]
# recommended items ids : [1221  527  593 1617 1197  912 1210 1198 1196  260]
# recommened items :
#  [['Godfather: Part II, The (1974)' 'Action|Crime|Drama']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['L.A. Confidential (1997)' 'Crime|Film-Noir|Mystery|Thriller']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Casablanca (1942)' 'Drama|Romance|War']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.5, dcg : 2.207, idcg : 4.544, ndcg : 0.486, reward : 1.5
#
# precision : 0.5, ngcg : 0.48571574856977245, episode_reward : 1.5
#
# user_id : 4853, rated_items_length:38
# history items :
#  [['Jewel of the Nile, The (1985)' 'Action|Adventure|Comedy|Romance']
#  ['Escape from New York (1981)' 'Action|Adventure|Sci-Fi|Thriller']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Rain Man (1988)' 'Drama']
#  ['Donnie Brasco (1997)' 'Crime|Drama']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)'
#   'Adventure|Comedy|Sci-Fi']
#  ['Hairspray (1988)' 'Comedy|Drama']
#  ['Babe (1995)' "Children's|Comedy|Drama"]
#  ['Animal House (1978)' 'Comedy']]
# recommended items ids : [ 608  858  527 2028  593 1270 1196 1617 1198  260]
# recommened items :
#  [['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['L.A. Confidential (1997)' 'Crime|Film-Noir|Mystery|Thriller']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.4, dcg : 1.421, idcg : 4.544, ndcg : 0.313, reward : 0.5
#
# precision : 0.4, ngcg : 0.31280477890197517, episode_reward : 0.5
#
# user_id : 4854, rated_items_length:164
# history items :
#  [['Closer You Get, The (2000)' 'Comedy|Romance']
#  ['King in New York, A (1957)' 'Comedy|Drama']
#  ['Howling II: Your Sister Is a Werewolf (1985)' 'Horror']
#  ['Searchers, The (1956)' 'Western']
#  ['Cold Comfort Farm (1995)' 'Comedy']
#  ['Beautician and the Beast, The (1997)' 'Comedy|Romance']
#  ['Autumn Sonata (Höstsonaten ) (1978)' 'Drama']
#  ['Odd Couple II, The (1998)' 'Comedy']
#  ['Godfather: Part III, The (1990)' 'Action|Crime|Drama']
#  ['Battleship Potemkin, The (Bronenosets Potyomkin) (1925)' 'Drama|War']]
# recommended items ids : [ 593  608  858 2858 1197 1270 1210 1196 1198  260]
# recommened items :
#  [['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.3, dcg : 1.032, idcg : 4.544, ndcg : 0.227, reward : -1.5
#
# precision : 0.3, ngcg : 0.22716217481924803, episode_reward : -1.5
#
# user_id : 4855, rated_items_length:219
# history items :
#  [['Hunt for Red October, The (1990)' 'Action|Thriller']
#  ['Strictly Ballroom (1992)' 'Comedy|Romance']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ["Dante's Peak (1997)" 'Action|Thriller']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ["'burbs, The (1989)" 'Comedy']
#  ['101 Dalmatians (1996)' "Children's|Comedy"]
#  ['12 Angry Men (1957)' 'Drama']
#  ['2001: A Space Odyssey (1968)' 'Drama|Mystery|Sci-Fi|Thriller']
#  ['8 Heads in a Duffel Bag (1997)' 'Comedy']]
# recommended items ids : [1198 1270  110 2571 2028  318  589  260  527 1196]
# recommened items :
#  [['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['Matrix, The (1999)' 'Action|Sci-Fi|Thriller']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['Shawshank Redemption, The (1994)' 'Drama']
#  ['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']]
# precision : 0.6, dcg : 2.411, idcg : 4.544, ndcg : 0.531, reward : 3.0
#
# precision : 0.6, ngcg : 0.5305455297539706, episode_reward : 3.0
#
# user_id : 4856, rated_items_length:79
# history items :
#  [['Last of the Mohicans, The (1992)' 'Action|Romance|War']
#  ['Wings of Desire (Der Himmel über Berlin) (1987)'
#   'Comedy|Drama|Romance']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Eyes Without a Face (1959)' 'Horror']
#  ['Annie Hall (1977)' 'Comedy|Romance']
#  ['Splash (1984)' 'Comedy|Fantasy|Romance']
#  ['Henry: Portrait of a Serial Killer, Part 2 (1996)' 'Crime|Horror']
#  ['Shanghai Noon (2000)' 'Action']
#  ['Croupier (1998)' 'Crime|Drama']
#  ['High Fidelity (2000)' 'Comedy']]
# recommended items ids : [1259 2396  858 1196 1270  527 2858  593 1197  260]
# recommened items :
#  [['Stand by Me (1986)' 'Adventure|Comedy|Drama']
#  ['Shakespeare in Love (1998)' 'Comedy|Romance']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.1, dcg : 0.333, idcg : 4.544, ndcg : 0.073, reward : -3.0
#
# precision : 0.1, ngcg : 0.07336392209936005, episode_reward : -3.0
#
# user_id : 4857, rated_items_length:61
# history items :
#  [['Breakfast Club, The (1985)' 'Comedy|Drama']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Lost World: Jurassic Park, The (1997)'
#   'Action|Adventure|Sci-Fi|Thriller']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Civil Action, A (1998)' 'Drama']
#  ["One Flew Over the Cuckoo's Nest (1975)" 'Drama']
#  ['Patriot Games (1992)' 'Action|Thriller']
#  ['Jurassic Park (1993)' 'Action|Adventure|Sci-Fi']
#  ['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ['Dark City (1998)' 'Film-Noir|Sci-Fi|Thriller']]
# recommended items ids : [1197  356  593 2858 2762 1210  608  858 1198 1196]
# recommened items :
#  [['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Forrest Gump (1994)' 'Comedy|Romance|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']]
# precision : 0.3, dcg : 1.220, idcg : 4.544, ndcg : 0.269, reward : -2.0
#
# precision : 0.3, ngcg : 0.2685529228900211, episode_reward : -2.0
#
# user_id : 4858, rated_items_length:113
# history items :
#  [['Michael (1996)' 'Comedy|Romance']
#  ['Godfather: Part II, The (1974)' 'Action|Crime|Drama']
#  ['Friday the 13th: The Final Chapter (1984)' 'Horror']
#  ['American President, The (1995)' 'Comedy|Drama|Romance']
#  ['Taxi Driver (1976)' 'Drama|Thriller']
#  ['Green Mile, The (1999)' 'Drama|Thriller']
#  ['True Grit (1969)' 'Adventure|Western']
#  ['Being John Malkovich (1999)' 'Comedy']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['American Movie (1999)' 'Documentary']]
# recommended items ids : [3578 1196  593  318 1198  912 1197  260 2858  527]
# recommened items :
#  [['Gladiator (2000)' 'Action|Drama']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Shawshank Redemption, The (1994)' 'Drama']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Casablanca (1942)' 'Drama|Romance|War']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ["Schindler's List (1993)" 'Drama|War']]
# precision : 0.7, dcg : 2.854, idcg : 4.544, ndcg : 0.628, reward : 5.5
#
# precision : 0.7, ngcg : 0.6281460426238844, episode_reward : 5.5
#
# user_id : 4859, rated_items_length:43
# history items :
#  [['Virgin Suicides, The (1999)' 'Comedy|Drama']
#  ['Titanic (1953)' 'Action|Drama']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['Philadelphia (1993)' 'Drama']
#  ['Forrest Gump (1994)' 'Comedy|Romance|War']
#  ['Father of the Bride (1950)' 'Comedy']
#  ['Mr. Mom (1983)' 'Comedy|Drama']
#  ['M*A*S*H (1970)' 'Comedy|War']
#  ['Heathers (1989)' 'Comedy']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']]
# recommended items ids : [2028  318  858  527 1210  608 1198  593 1196  260]
# recommened items :
#  [['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['Shawshank Redemption, The (1994)' 'Drama']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.1, dcg : 0.387, idcg : 4.544, ndcg : 0.085, reward : -4.0
#
# precision : 0.1, ngcg : 0.08514311764162098, episode_reward : -4.0
#
# user_id : 4860, rated_items_length:48
# history items :
#  [['Dangerous Liaisons (1988)' 'Drama|Romance']
#  ['Jaws (1975)' 'Action|Horror']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Jurassic Park (1993)' 'Action|Adventure|Sci-Fi']
#  ['Back to the Future Part II (1989)' 'Comedy|Sci-Fi']
#  ['Fight Club (1999)' 'Drama']
#  ['Insider, The (1999)' 'Drama']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Talented Mr. Ripley, The (1999)' 'Drama|Mystery|Thriller']
#  ['Galaxy Quest (1999)' 'Adventure|Comedy|Sci-Fi']]
# recommended items ids : [  34  589 2858 2571 1617  527  296  608  318  593]
# recommened items :
#  [['Babe (1995)' "Children's|Comedy|Drama"]
#  ['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Matrix, The (1999)' 'Action|Sci-Fi|Thriller']
#  ['L.A. Confidential (1997)' 'Crime|Film-Noir|Mystery|Thriller']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Pulp Fiction (1994)' 'Crime|Drama']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Shawshank Redemption, The (1994)' 'Drama']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']]
# precision : 0.5, dcg : 1.755, idcg : 4.544, ndcg : 0.386, reward : 2.5
#
# precision : 0.5, ngcg : 0.3863474142462608, episode_reward : 2.5
#
# user_id : 4861, rated_items_length:197
# history items :
#  [['Lovers of the Arctic Circle, The (Los Amantes del Círculo Polar) (1998)'
#   'Drama|Romance']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Karate Kid III, The (1989)' 'Action|Adventure|Drama']
#  ['Jurassic Park (1993)' 'Action|Adventure|Sci-Fi']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Dances with Wolves (1990)' 'Adventure|Drama|Western']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Run Lola Run (Lola rennt) (1998)' 'Action|Crime|Romance']
#  ['Thelma & Louise (1991)' 'Action|Drama']]
# recommended items ids : [1097  593 1197  589 2762 2396 2858 1196 1198  260]
# recommened items :
#  [['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Shakespeare in Love (1998)' 'Comedy|Romance']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.5, dcg : 1.870, idcg : 4.544, ndcg : 0.412, reward : 1.0
#
# precision : 0.5, ngcg : 0.4115325995630326, episode_reward : 1.0
#
# user_id : 4862, rated_items_length:94
# history items :
#  [['League of Their Own, A (1992)' 'Comedy|Drama']
#  ['North by Northwest (1959)' 'Drama|Thriller']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Brady Bunch Movie, The (1995)' 'Comedy']
#  ['March of the Wooden Soldiers (a.k.a. Laurel & Hardy in Toyland) (1934)'
#   'Comedy']
#  ['Assassins (1995)' 'Thriller']
#  ['Rocketeer, The (1991)' 'Action|Adventure|Sci-Fi']
#  ['High Fidelity (2000)' 'Comedy']
#  ['Chicken Run (2000)' "Animation|Children's|Comedy"]
#  ['Gladiator (2000)' 'Action|Drama']]
# recommended items ids : [1036 1374  589 1197 1210 1200 1240 1198 1270 1196]
# recommened items :
#  [['Die Hard (1988)' 'Action|Thriller']
#  ['Star Trek: The Wrath of Khan (1982)' 'Action|Adventure|Sci-Fi']
#  ['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Aliens (1986)' 'Action|Sci-Fi|Thriller|War']
#  ['Terminator, The (1984)' 'Action|Sci-Fi|Thriller']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']]
# precision : 0.9, dcg : 4.113, idcg : 4.544, ndcg : 0.905, reward : 6.5
#
# precision : 0.9, ngcg : 0.9052116356304493, episode_reward : 6.5
#
# user_id : 4863, rated_items_length:31
# history items :
#  [['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Right Stuff, The (1983)' 'Drama']
#  ["City Slickers II: The Legend of Curly's Gold (1994)" 'Comedy|Western']
#  ['Man Without a Face, The (1993)' 'Drama']
#  ['Tomorrow Never Dies (1997)' 'Action|Romance|Thriller']
#  ['Star Wars: Episode I - The Phantom Menace (1999)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Toy Story 2 (1999)' "Animation|Children's|Comedy"]
#  ['To Be or Not to Be (1942)' 'Comedy|Drama|War']
#  ['Groundhog Day (1993)' 'Comedy|Romance']]
# recommended items ids : [ 318  608  858 2858 1210 1198 1196  593  260  527]
# recommened items :
#  [['Shawshank Redemption, The (1994)' 'Drama']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ["Schindler's List (1993)" 'Drama|War']]
# precision : 0.0, dcg : 0.000, idcg : 4.544, ndcg : 0.000, reward : -5.0
#
# precision : 0.0, ngcg : 0.0, episode_reward : -5.0
#
# user_id : 4864, rated_items_length:33
# history items :
#  [['Scrooged (1988)' 'Comedy']
#  ['2010 (1984)' 'Mystery|Sci-Fi']
#  ['Simple Plan, A (1998)' 'Crime|Thriller']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['Money Pit, The (1986)' 'Comedy']
#  ['Last of the Mohicans, The (1992)' 'Action|Romance|War']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Close Shave, A (1995)' 'Animation|Comedy|Thriller']
#  ['Gold Rush, The (1925)' 'Comedy']
#  ['Being John Malkovich (1999)' 'Comedy']]
# recommended items ids : [1387  593 1210 2762 1097  527 1196  858 1198  260]
# recommened items :
#  [['Jaws (1975)' 'Action|Horror']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.0, dcg : 0.000, idcg : 4.544, ndcg : 0.000, reward : -5.0
#
# precision : 0.0, ngcg : 0.0, episode_reward : -5.0
#
# user_id : 4865, rated_items_length:246
# history items :
#  [['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ['Honey, I Shrunk the Kids (1989)'
#   "Adventure|Children's|Comedy|Fantasy|Sci-Fi"]
#  ['Maurice (1987)' 'Drama|Romance']
#  ['Casablanca (1942)' 'Drama|Romance|War']
#  ['Gay Divorcee, The (1934)' 'Comedy|Musical|Romance']
#  ['Alien Nation (1988)' 'Crime|Drama|Sci-Fi']
#  ['Battleship Potemkin, The (Bronenosets Potyomkin) (1925)' 'Drama|War']
#  ['Badlands (1973)' 'Crime|Drama']
#  ['Brother from Another Planet, The (1984)' 'Drama|Sci-Fi']
#  ['Blowup (1966)' 'Drama|Mystery']]
# recommended items ids : [ 858 1197 2858 2762 1240  110 1210 1196 1198  260]
# recommened items :
#  [['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Terminator, The (1984)' 'Action|Sci-Fi|Thriller']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.5, dcg : 2.721, idcg : 4.544, ndcg : 0.599, reward : 2.0
#
# precision : 0.5, ngcg : 0.5988751049740155, episode_reward : 2.0
#
# user_id : 4866, rated_items_length:75
# history items :
#  [['Anne Frank Remembered (1995)' 'Documentary']
#  ['Jurassic Park (1993)' 'Action|Adventure|Sci-Fi']
#  ['Harry and the Hendersons (1987)' 'Comedy']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Naked Gun 33 1/3: The Final Insult (1994)' 'Comedy']
#  ['Mary Poppins (1964)' "Children's|Comedy|Musical"]
#  ['Young Frankenstein (1974)' 'Comedy|Horror']
#  ['Tom Jones (1963)' 'Comedy']
#  ['Bell, Book and Candle (1958)' 'Comedy|Romance']
#  ['Groundhog Day (1993)' 'Comedy|Romance']]
# recommended items ids : [ 858  608 2858  527 1097  593 1270 1196  260 1198]
# recommened items :
#  [['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']]
# precision : 0.1, dcg : 0.333, idcg : 4.544, ndcg : 0.073, reward : -3.5
#
# precision : 0.1, ngcg : 0.07336392209936005, episode_reward : -3.5
#
# user_id : 4867, rated_items_length:622
# history items :
#  [["Schindler's List (1993)" 'Drama|War']
#  ['From Russia with Love (1963)' 'Action']
#  ['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ['Phantom, The (1996)' 'Adventure']
#  ['Mighty Aphrodite (1995)' 'Comedy']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['That Darn Cat! (1965)' "Children's|Comedy|Mystery"]
#  ['Chicken Run (2000)' "Animation|Children's|Comedy"]
#  ['City of Lost Children, The (1995)' 'Adventure|Sci-Fi']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']]
# recommended items ids : [1240 1270 2028 2762  318  858 1210  593 1198 1196]
# recommened items :
# ...
# recommened items :
#  [['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Shawshank Redemption, The (1994)' 'Drama']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']]
# precision : 0.0, dcg : 0.000, idcg : 4.544, ndcg : 0.000, reward : -5.0
#
# precision : 0.0, ngcg : 0.0, episode_reward : -5.0
#
# user_id : 6030, rated_items_length:115
# history items :
#  [['Mystery Science Theater 3000: The Movie (1996)' 'Comedy|Sci-Fi']
#  ['Class (1983)' 'Comedy']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['Addams Family, The (1991)' 'Comedy']
#  ['Gone with the Wind (1939)' 'Drama|Romance|War']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Tarzan (1999)' "Animation|Children's"]
#  ['Star Wars: Episode I - The Phantom Menace (1999)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Messenger: The Story of Joan of Arc, The (1999)' 'Drama|War']
#  ['Aliens (1986)' 'Action|Sci-Fi|Thriller|War']]
# recommended items ids : [ 589  527 1197 2858  593 1270 1210 1198 1196  260]
# recommened items :
#  [['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.4, dcg : 1.946, idcg : 4.544, ndcg : 0.428, reward : 0.5
#
# precision : 0.4, ngcg : 0.42836504693009625, episode_reward : 0.5
#
# user_id : 6031, rated_items_length:51
# history items :
#  [['Kingpin (1996)' 'Comedy']
#  ['Casablanca (1942)' 'Drama|Romance|War']
#  ['Lethal Weapon 2 (1989)' 'Action|Comedy|Crime|Drama']
#  ['Conspiracy Theory (1997)' 'Action|Mystery|Romance|Thriller']
#  ['Jack (1996)' 'Comedy|Drama']
#  ['Rain Man (1988)' 'Drama']
#  ['House Arrest (1996)' 'Comedy']
#  ['Shooting Fish (1997)' 'Romance']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Pagemaster, The (1994)'
#   "Action|Adventure|Animation|Children's|Fantasy"]]
# recommended items ids : [1210 1240 1197 1196  318 1198  260 2571  589  527]
# recommened items :
#  [['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Terminator, The (1984)' 'Action|Sci-Fi|Thriller']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Shawshank Redemption, The (1994)' 'Drama']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Matrix, The (1999)' 'Action|Sci-Fi|Thriller']
#  ['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ["Schindler's List (1993)" 'Drama|War']]
# precision : 0.3, dcg : 1.946, idcg : 4.544, ndcg : 0.428, reward : -1.0
#
# precision : 0.3, ngcg : 0.42838543210841196, episode_reward : -1.0
#
# user_id : 6032, rated_items_length:104
# history items :
#  [['Bonnie and Clyde (1967)' 'Crime|Drama']
#  ['Pinocchio (1940)' "Animation|Children's"]
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Freaky Friday (1977)' "Children's|Comedy"]
#  ['Arthur (1981)' 'Comedy|Romance']
#  ['Caddyshack (1980)' 'Comedy']
#  ['Network (1976)' 'Comedy|Drama']
#  ['Outlaw Josey Wales, The (1976)' 'Western']
#  ['True Grit (1969)' 'Adventure|Western']]
# recommended items ids : [1968  858 1394 1198  260 2716 2804 1304 1270 1259]
# recommened items :
#  [['Breakfast Club, The (1985)' 'Comedy|Drama']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Raising Arizona (1987)' 'Comedy']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Ghostbusters (1984)' 'Comedy|Horror']
#  ['Christmas Story, A (1983)' 'Comedy|Drama']
#  ['Butch Cassidy and the Sundance Kid (1969)' 'Action|Comedy|Western']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Stand by Me (1986)' 'Adventure|Comedy|Drama']]
# precision : 0.4, dcg : 1.505, idcg : 4.544, ndcg : 0.331, reward : -0.5
#
# precision : 0.4, ngcg : 0.3312392961638527, episode_reward : -0.5
#
# user_id : 6033, rated_items_length:60
# history items :
#  [['Total Recall (1990)' 'Action|Adventure|Sci-Fi|Thriller']
#  ['Star Wars: Episode I - The Phantom Menace (1999)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Apple Dumpling Gang Rides Again, The (1979)'
#   "Children's|Comedy|Western"]
#  ['Old Yeller (1957)' "Children's|Drama"]
#  ["One Flew Over the Cuckoo's Nest (1975)" 'Drama']
#  ['Arachnophobia (1990)' 'Action|Comedy|Sci-Fi|Thriller']
#  ['13th Warrior, The (1999)' 'Action|Horror|Thriller']
#  ['Civil Action, A (1998)' 'Drama']
#  ['Entrapment (1999)' 'Crime|Thriller']
#  ["General's Daughter, The (1999)" 'Drama|Thriller']]
# recommended items ids : [ 589 1200 2028  527 1240 1270 1198 1210 1196  260]
# recommened items :
#  [['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ['Aliens (1986)' 'Action|Sci-Fi|Thriller|War']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Terminator, The (1984)' 'Action|Sci-Fi|Thriller']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.5, dcg : 1.739, idcg : 4.544, ndcg : 0.383, reward : 0.5
#
# precision : 0.5, ngcg : 0.3827160388385181, episode_reward : 0.5
#
# user_id : 6034, rated_items_length:21
# history items :
#  [["Schindler's List (1993)" 'Drama|War']
#  ['Bonfire of the Vanities (1990)' 'Comedy']
#  ['Ace Ventura: Pet Detective (1994)' 'Comedy']
#  ['Carrie (1976)' 'Horror']
#  ['Outlaw, The (1943)' 'Western']
#  ['Blade Runner (1982)' 'Film-Noir|Sci-Fi']
#  ['Chinatown (1974)' 'Film-Noir|Mystery|Thriller']
#  ['Maltese Falcon, The (1941)' 'Film-Noir|Mystery']
#  ['Double Indemnity (1944)' 'Crime|Film-Noir']
#  ['Touch of Evil (1958)' 'Crime|Film-Noir|Thriller']]
# recommended items ids : [1387 1210 2858  356  593  858 1196 1198  260  608]
# recommened items :
#  [['Jaws (1975)' 'Action|Horror']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Forrest Gump (1994)' 'Comedy|Romance|War']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']]
# precision : 0.0, dcg : 0.000, idcg : 4.544, ndcg : 0.000, reward : -5.0
#
# precision : 0.0, ngcg : 0.0, episode_reward : -5.0
#
# user_id : 6035, rated_items_length:280
# history items :
#  [['Apple Dumpling Gang, The (1975)' "Children's|Comedy|Western"]
#  ["Breakfast at Tiffany's (1961)" 'Drama|Romance']
#  ['Leaving Las Vegas (1995)' 'Drama|Romance']
#  ['Philadelphia Story, The (1940)' 'Comedy|Romance']
#  ["One Flew Over the Cuckoo's Nest (1975)" 'Drama']
#  ["Astronaut's Wife, The (1999)" 'Sci-Fi|Thriller']
#  ['Star Wars: Episode I - The Phantom Menace (1999)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Galaxy Quest (1999)' 'Adventure|Comedy|Sci-Fi']
#  ['Twelve Monkeys (1995)' 'Drama|Sci-Fi']
#  ['Matrix, The (1999)' 'Action|Sci-Fi|Thriller']]
# recommended items ids : [1198  593 2028  527  318  260 1210 1197  589 1196]
# recommened items :
#  [['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Shawshank Redemption, The (1994)' 'Drama']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Terminator 2: Judgment Day (1991)' 'Action|Sci-Fi|Thriller']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']]
# precision : 0.4, dcg : 1.440, idcg : 4.544, ndcg : 0.317, reward : 0.5
#
# precision : 0.4, ngcg : 0.31691619230948354, episode_reward : 0.5
#
# user_id : 6036, rated_items_length:888
# history items :
#  [['Titanic (1997)' 'Drama|Romance']
#  ['Bulworth (1998)' 'Comedy']
#  ['Teenage Mutant Ninja Turtles (1990)' "Action|Children's|Fantasy"]
#  ['View to a Kill, A (1985)' 'Action']
#  ['Faculty, The (1998)' 'Horror|Sci-Fi']
#  ['Austin Powers: The Spy Who Shagged Me (1999)' 'Comedy']
#  ['10 Things I Hate About You (1999)' 'Comedy|Romance']
#  ['American Pie (1999)' 'Comedy']
#  ['Arlington Road (1999)' 'Thriller']
#  ["Astronaut's Wife, The (1999)" 'Sci-Fi|Thriller']]
# recommended items ids : [ 527 1197 1617 2858  593  858 1198 1210 1196  260]
# recommened items :
#  [["Schindler's List (1993)" 'Drama|War']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['L.A. Confidential (1997)' 'Crime|Film-Noir|Mystery|Thriller']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.7, dcg : 2.872, idcg : 4.544, ndcg : 0.632, reward : 6.0
#
# precision : 0.7, ngcg : 0.6320787427864673, episode_reward : 6.0
#
# user_id : 6037, rated_items_length:202
# history items :
#  [['Godzilla (1998)' 'Action|Sci-Fi']
#  ['Faces (1968)' 'Drama']
#  ['Manchurian Candidate, The (1962)' 'Film-Noir|Thriller']
#  ['Saving Private Ryan (1998)' 'Action|Drama|War']
#  ['Outlaw Josey Wales, The (1976)' 'Western']
#  ['Cider House Rules, The (1999)' 'Drama']
#  ['Welcome to the Dollhouse (1995)' 'Comedy|Drama']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Godfather: Part II, The (1974)' 'Action|Crime|Drama']
#  ['Casablanca (1942)' 'Drama|Romance|War']]
# recommended items ids : [   1 1270  593 3114 2804 1196  527  260 2858 1198]
# recommened items :
#  [['Toy Story (1995)' "Animation|Children's|Comedy"]
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Toy Story 2 (1999)' "Animation|Children's|Comedy"]
#  ['Christmas Story, A (1983)' 'Comedy|Drama']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']]
# precision : 0.6, dcg : 2.267, idcg : 4.544, ndcg : 0.499, reward : 3.0
#
# precision : 0.6, ngcg : 0.4990267326507382, episode_reward : 3.0
#
# user_id : 6038, rated_items_length:20
# history items :
#  [['Muppet Movie, The (1979)' "Children's|Comedy"]
#  ['Gone with the Wind (1939)' 'Drama|Romance|War']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ["St. Elmo's Fire (1985)" 'Drama|Romance']
#  ['Jaws (1975)' 'Action|Horror']
#  ['Forrest Gump (1994)' 'Comedy|Romance|War']
#  ['Fish Called Wanda, A (1988)' 'Comedy']
#  ['Wrong Trousers, The (1993)' 'Animation|Comedy']
#  ['Cool Hand Luke (1967)' 'Comedy|Drama']
#  ['Ghostbusters (1984)' 'Comedy|Horror']]
# recommended items ids : [2858  608  858 1270 1097  593 1196  527  260 1198]
# recommened items :
#  [['American Beauty (1999)' 'Comedy|Drama']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['E.T. the Extra-Terrestrial (1982)' "Children's|Drama|Fantasy|Sci-Fi"]
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']]
# precision : 0.0, dcg : 0.000, idcg : 4.544, ndcg : 0.000, reward : -5.0
#
# precision : 0.0, ngcg : 0.0, episode_reward : -5.0
#
# user_id : 6039, rated_items_length:123
# history items :
#  [['Taxi Driver (1976)' 'Drama|Thriller']
#  ['Nell (1994)' 'Drama']
#  ['Doctor Zhivago (1965)' 'Drama|Romance|War']
#  ['Annie Hall (1977)' 'Comedy|Romance']
#  ['Notorious (1946)' 'Film-Noir|Romance|Thriller']
#  ['My Man Godfrey (1936)' 'Comedy']
#  ['Harvey (1950)' 'Comedy']
#  ['General, The (1927)' 'Comedy']
#  ['Go West (1925)' 'Comedy']
#  ['M*A*S*H (1970)' 'Comedy|War']]
# recommended items ids : [ 919  858  527 2858 1210 1197 1270 1196 1198  260]
# recommened items :
#  [['Wizard of Oz, The (1939)' "Adventure|Children's|Drama|Musical"]
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Star Wars: Episode VI - Return of the Jedi (1983)'
#   'Action|Adventure|Romance|Sci-Fi|War']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']]
# precision : 0.6, dcg : 2.996, idcg : 4.544, ndcg : 0.659, reward : 2.0
#
# precision : 0.6, ngcg : 0.6594803070902429, episode_reward : 2.0
#
# user_id : 6040, rated_items_length:341
# history items :
#  [['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Babe: Pig in the City (1998)' "Children's|Comedy"]
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Rain Man (1988)' 'Drama']
#  ['Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)'
#   'Action|Drama']
#  ['Walkabout (1971)' 'Drama']
#  ['Burnt By the Sun (Utomlyonnye solntsem) (1994)' 'Drama']
#  ['Places in the Heart (1984)' 'Drama']
#  ['Ciao, Professore! (Io speriamo che me la cavo ) (1993)' 'Drama']
#  ['No Way Out (1987)' 'Thriller']]
# recommended items ids : [ 296 1198  318  527 1196 1197  260 2858 1270  608]
# recommened items :
#  [['Pulp Fiction (1994)' 'Crime|Drama']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Shawshank Redemption, The (1994)' 'Drama']
#  ["Schindler's List (1993)" 'Drama|War']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Princess Bride, The (1987)' 'Action|Adventure|Comedy|Romance']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['American Beauty (1999)' 'Comedy|Drama']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Fargo (1996)' 'Crime|Drama|Thriller']]
# precision : 0.6, dcg : 2.869, idcg : 4.544, ndcg : 0.631, reward : 3.0
#
# precision : 0.6, ngcg : 0.6313419460517601, episode_reward : 3.0
#
# precision@10 : 0.3619205298013247, ndcg@10 : 0.35086070460747965
